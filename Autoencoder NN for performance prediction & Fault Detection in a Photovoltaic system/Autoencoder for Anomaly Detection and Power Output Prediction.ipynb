# %% [markdown]
# # SMARTTRACK AI DEEP LEARNING ASSESSMENT

# %% [markdown]
# # AUTOENCODER for Performance Prediction and Fault Detection in a Photovoltaic System

# %% [markdown]
# **Name: HARISH WATHORE
# <br>
# Roll Number: 20101017
# <br>
# Department of Aerospace Engineering
# <br>
# Indian Institute of Technology Kanpur
# <br>**

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
# Load normal data, data with no anomalies
normal_data = pd.read_csv('PV_dataset_4.csv')

# Load anomaly data
anomaly_data = pd.read_csv('PV_dataset_anomalies_v1_Pac.csv')

# %%
# Add labels for normal and anomaly data
normal_data['Label'] = 0  # 0 represents normal data
anomaly_data['Label'] = 1  # 1 represents anomalies

# %%
# Combine normal and anomaly data together
combined_data = pd.concat([normal_data, anomaly_data], ignore_index=True)

# %%
# Shuffle the combined dataset
combined_data = combined_data.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
# Extract features and labels for training
features = combined_data.drop('Label', axis=1)
labels = combined_data['Label']
target_pac = combined_data['Pac']

# %%
# Split the data into training and testing of anomaly detection and also split data for Power AC prediction

X_train, X_test, y_train, y_test, pac_train, pac_test = train_test_split(
    features, labels, target_pac, test_size=0.2, random_state=42
)

# %%
# Standardize the input features for faster convergence
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Autoencoder Model for the anomaly detection
model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(X_train_scaled.shape[1], activation=None)  
])

# %%
# Compiling the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the autoencoder on Normal Data
history = model.fit(
    X_train_scaled[y_train == 0],  # Use only normal data for training
    X_train_scaled[y_train == 0],  # Target is the same as input for autoencoder
    epochs=50,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# 1021/1021 [==============================] - 3s 2ms/step - loss: 0.0589 - val_loss: 7.2471e-04
# Epoch 2/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.7767e-04 - val_loss: 2.9371e-04
# Epoch 3/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 2.4200e-04 - val_loss: 1.6749e-04
# Epoch 4/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.6773e-04 - val_loss: 1.4714e-04
# Epoch 5/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.4390e-04 - val_loss: 9.7641e-05
# Epoch 6/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.2867e-04 - val_loss: 1.3912e-04
# Epoch 7/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.0169e-04 - val_loss: 9.1585e-05
# Epoch 8/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 9.4773e-05 - val_loss: 1.0777e-04
# Epoch 9/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 8.5807e-05 - val_loss: 6.7326e-05
# Epoch 10/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 8.9344e-05 - val_loss: 1.5584e-04
# Epoch 11/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 7.7401e-05 - val_loss: 4.8413e-05
# Epoch 12/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 7.9446e-05 - val_loss: 6.1243e-05
# Epoch 13/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 5.9214e-05 - val_loss: 7.0111e-05
# Epoch 14/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 6.4326e-05 - val_loss: 5.0125e-05
# Epoch 15/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 6.7308e-05 - val_loss: 3.6519e-05
# Epoch 16/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 5.6362e-05 - val_loss: 9.3321e-05
# Epoch 17/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 6.4546e-05 - val_loss: 6.6345e-05
# Epoch 18/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.9726e-05 - val_loss: 3.2939e-05
# Epoch 19/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 5.2120e-05 - val_loss: 6.5345e-05
# Epoch 20/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 5.2136e-05 - val_loss: 4.9583e-05
# Epoch 21/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 5.1779e-05 - val_loss: 6.4732e-05
# Epoch 22/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.5164e-05 - val_loss: 1.1075e-04
# Epoch 23/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 5.2767e-05 - val_loss: 3.8177e-05
# Epoch 24/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.6697e-05 - val_loss: 5.9319e-05
# Epoch 25/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 6.9183e-05 - val_loss: 3.3473e-05
# Epoch 26/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.5248e-05 - val_loss: 2.8172e-05
# Epoch 27/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.7223e-05 - val_loss: 3.4850e-05
# Epoch 28/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.3390e-05 - val_loss: 4.5832e-05
# Epoch 29/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.3712e-05 - val_loss: 3.2162e-05
# Epoch 30/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.3889e-05 - val_loss: 5.3851e-05
# Epoch 31/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.0244e-05 - val_loss: 4.3656e-05
# Epoch 32/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.9482e-05 - val_loss: 3.0291e-05
# Epoch 33/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.6240e-05 - val_loss: 1.6957e-05
# Epoch 34/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.3034e-05 - val_loss: 2.9314e-05
# Epoch 35/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.5574e-05 - val_loss: 3.9862e-05
# Epoch 36/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.9176e-05 - val_loss: 1.1615e-04
# Epoch 37/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.7004e-05 - val_loss: 4.2629e-05
# Epoch 38/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.2071e-05 - val_loss: 1.8971e-05
# Epoch 39/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.3948e-05 - val_loss: 2.4454e-05
# Epoch 40/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.6695e-05 - val_loss: 2.2530e-05
# Epoch 41/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 2.7699e-05 - val_loss: 3.5673e-05
# Epoch 42/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.8435e-05 - val_loss: 5.6611e-05
# Epoch 43/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.2219e-05 - val_loss: 4.9690e-05
# Epoch 44/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 2.4605e-05 - val_loss: 2.8093e-05
# Epoch 45/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.9563e-05 - val_loss: 2.6522e-05
# Epoch 46/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.3020e-05 - val_loss: 1.0990e-05
# Epoch 47/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.8753e-05 - val_loss: 1.2033e-05
# Epoch 48/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.9499e-05 - val_loss: 1.1913e-05
# Epoch 49/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.1426e-05 - val_loss: 2.1316e-05
# Epoch 50/50
# 1021/1021 [==============================] - 2s 2ms/step - loss: 5.4547e-05 - val_loss: 1.5134e-05

# %%
# Access the training loss and validation loss over epochs
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Plot the training loss and validation loss for Anomaly Detection
import matplotlib.pyplot as plt

plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Autoencoder Anomaly Model Loss Plot')
plt.show()

# %%
# Testing the autoencoder on the test set
test_predictions = model.predict(X_test_scaled)
test_mse = np.mean(np.square(X_test_scaled - test_predictions), axis=1)  # Mean squared error for each sample

# Setting a threshold for anomaly detection based on training performance
threshold_percentage = 90 #90 Because, the anomaly dataset I made had sudden 5% of Pac values drop by 90% because of sudden low voltage. 
threshold = np.percentile(test_mse, threshold_percentage)

# Identify the anomalies in our test set
test_anomalies = test_mse > threshold

# Print the number of anomalies present in the test set
print(f'Number of anomalies in the test set: {np.sum(test_anomalies)}')
# Out:
# 639/639 [==============================] - 1s 1ms/step
# Number of anomalies in the test set: 2042

# %%
# Visualize the test set reconstruction errors
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(range(len(test_mse)), test_mse, c=test_anomalies, cmap='coolwarm', s=10)
plt.axhline(y=threshold, color='r', linestyle='--', label='Threshold')
plt.xlabel('Sample Index')
plt.ylabel('Reconstruction Error (MSE)')
plt.title('Test Set Reconstruction Errors and Anomalies')
plt.legend()
plt.show()

# %%
# Fine-tune the autoencoder for Power AC prediction
model.pop()  # Remove the last layer (output layer)
model.add(tf.keras.layers.Dense(1, activation=None))  # Add a single output neuron for Pac prediction
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the fine-tuned autoencoder for Power AC prediction
fine_tune_history = model.fit(
    X_train_scaled, pac_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# 2042/2042 [==============================] - 5s 2ms/step - loss: 3619.9438 - val_loss: 16.1879
# Epoch 2/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 9.3077 - val_loss: 4.3743
# Epoch 3/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 3.2255 - val_loss: 1.6890
# Epoch 4/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 2.2420 - val_loss: 0.8832
# Epoch 5/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.7243 - val_loss: 0.6789
# Epoch 6/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.5996 - val_loss: 0.6361
# Epoch 7/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.2145 - val_loss: 0.6606
# Epoch 8/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 3.4856 - val_loss: 0.8145
# Epoch 9/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.2641 - val_loss: 0.6091
# Epoch 10/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.3295 - val_loss: 0.5600
# Epoch 11/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.8432 - val_loss: 1.5795
# Epoch 12/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.6413 - val_loss: 0.3613
# Epoch 13/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.1796 - val_loss: 4.6709
# Epoch 14/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.9099 - val_loss: 0.2889
# Epoch 15/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.9682 - val_loss: 1.3769
# Epoch 16/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.8393 - val_loss: 0.7760
# Epoch 17/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.3590 - val_loss: 0.4824
# Epoch 18/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.1315 - val_loss: 0.8504
# Epoch 19/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.4846 - val_loss: 0.2816
# Epoch 20/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.8164 - val_loss: 0.6818
# Epoch 21/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.9126 - val_loss: 1.5909
# Epoch 22/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.0544 - val_loss: 0.5106
# Epoch 23/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.0401 - val_loss: 0.2141
# Epoch 24/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.9138 - val_loss: 0.2041
# Epoch 25/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.0442 - val_loss: 0.2243
# Epoch 26/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.8814 - val_loss: 0.2402
# Epoch 27/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.8086 - val_loss: 0.3689
# Epoch 28/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.5518 - val_loss: 2.4611
# Epoch 29/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.6072 - val_loss: 0.2355
# Epoch 30/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.7792 - val_loss: 0.1933
# Epoch 31/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.3012 - val_loss: 0.2359
# Epoch 32/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.7244 - val_loss: 51.3476
# Epoch 33/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.8266 - val_loss: 0.2517
# Epoch 34/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.1409 - val_loss: 0.2745
# Epoch 35/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.5979 - val_loss: 0.5663
# Epoch 36/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.6150 - val_loss: 1.2117
# Epoch 37/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.6485 - val_loss: 0.1345
# Epoch 38/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.1722 - val_loss: 0.1362
# Epoch 39/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.3464 - val_loss: 0.2871
# Epoch 40/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.6738 - val_loss: 1.3744
# Epoch 41/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.6787 - val_loss: 0.5135
# Epoch 42/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.7654 - val_loss: 0.1446
# Epoch 43/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.9910 - val_loss: 0.8724
# Epoch 44/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.5118 - val_loss: 0.2224
# Epoch 45/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.8792 - val_loss: 0.1061
# Epoch 46/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.8141 - val_loss: 0.3071
# Epoch 47/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.8639 - val_loss: 0.1839
# Epoch 48/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.8561 - val_loss: 0.1381
# Epoch 49/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 0.5661 - val_loss: 1.0180
# Epoch 50/50
# 2042/2042 [==============================] - 4s 2ms/step - loss: 1.0192 - val_loss: 0.5594

# %%
# Evaluating the fine-tuned model on the test set
pac_predictions = model.predict(X_test_scaled)
mse_pac = mean_squared_error(pac_test, pac_predictions.flatten())
print(f'Mean Squared Error on Test Set for Pac prediction: {mse_pac}')
# Out:
# 639/639 [==============================] - 1s 1ms/step
# Mean Squared Error on Test Set for Pac prediction: 0.5602977927849724

# %%
# Visualize the training loss and validation loss for the Power AC prediction task
plt.subplot(1, 2, 2)
plt.plot(fine_tune_history.history['loss'], label='Training Loss (Pac)')
plt.plot(fine_tune_history.history['val_loss'], label='Validation Loss (Pac)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Pac Loss Plot')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Evaluate the fine-tuned model on the test set
pac_predictions = model.predict(X_test_scaled)

# Create a DataFrame with true values, predictions, and features
result_df = pd.DataFrame({
    'True_Pac': pac_test,
    'Predicted_Pac': pac_predictions.flatten(),
    'Tm': X_test['Tm'],
    'Ta': X_test['Ta'],
    'Gir': X_test['Gir']
})

# Sort the DataFrame based on ascending values of 'Ta' and 'Gir'
result_df_sorted = result_df.sort_values(by=['Ta', 'Gir'])

# Save the sorted DataFrame to a CSV file
result_df_sorted.to_csv('auto_encoder_pac_predictions_sorted.csv', index=False)
# Out:
# 639/639 [==============================] - 1s 1ms/step

# %%
# Load the predictions with features from the CSV file
import_df = pd.read_csv('auto_encoder_pac_predictions_sorted.csv')

# Plot 'Ta' vs 'True_Pac' and 'Predicted_Pac' with smaller points
plt.scatter(import_df['Ta'], import_df['True_Pac'], label='True_Pac', s=1)  # Adjust 's' for size
plt.scatter(import_df['Ta'], import_df['Predicted_Pac'], label='Predicted_Pac', s=1)  # Adjust 's' for size
plt.xlabel('Ta')
plt.ylabel('Power Output (Pac)')
plt.title('True vs Predicted Power Output')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the predictions with features from the CSV file
import_df = pd.read_csv('auto_encoder_pac_predictions_sorted.csv')

# Filter the DataFrame for Ta = 25
selected_ta_df = import_df[import_df['Ta'] == 25]

# Plot 'Gir' vs 'True_Pac' and 'Predicted_Pac' for Ta = 25
plt.scatter(selected_ta_df['Gir'], selected_ta_df['True_Pac'], label='True_Pac', s=10)
plt.scatter(selected_ta_df['Gir'], selected_ta_df['Predicted_Pac'], label='Predicted_Pac', s=10)
plt.xlabel('Ground Level Sun Irradiance (Gir)')
plt.ylabel('Power Output (Pac)')
plt.title('True vs Predicted Power Output for Ta = 25')
plt.legend()
plt.show()
