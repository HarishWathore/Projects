# %% [markdown]
# # SMARTTRACK AI DEEP LEARNING ASSESSMENT

# %% [markdown]
# # Artificial Neural Network for Performance Prediction and Fault Detection in a Photovoltaic System

# %% [markdown]
# ## NOTE : This was just an experiment with simple ANN.
# ## Main Code Notebook is "Autoencoder for Anomaly Detection and Power Output Prediction.ipynb"

# %% [markdown]
# **Name: HARISH WATHORE
# <br>
# Roll Number: 20101017
# <br>
# Department of Aerospace Engineering
# <br>
# Indian Institute of Technology Kanpur
# <br>**

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# %%
# Load the dataset
data = pd.read_csv('PV_dataset_4.csv')

# Extract input features (Tm, Ta, Gir) and output target (Pac)
features = data[['Tm', 'Ta', 'Gir']]
target = data['Pac']

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Standardize the input features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Build the neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='swish', input_shape=(3,)),
    tf.keras.layers.Dense(32, activation='swish'),
    tf.keras.layers.Dense(1)  # Output layer, no activation for regression
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
tf.keras.backend.clear_session()

# %%
# Train the model
history = model.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 1021/1021 [==============================] - 3s 2ms/step - loss: 19097.5293 - val_loss: 2081.1582
# Epoch 2/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1595.7460 - val_loss: 1301.8859
# Epoch 3/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1047.1263 - val_loss: 849.8340
# Epoch 4/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 679.9797 - val_loss: 530.7708
# Epoch 5/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 441.3285 - val_loss: 361.3491
# Epoch 6/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 270.6908 - val_loss: 158.5048
# Epoch 7/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 112.9007 - val_loss: 73.9960
# Epoch 8/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 58.1654 - val_loss: 41.4815
# Epoch 9/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 34.3952 - val_loss: 24.4308
# Epoch 10/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 22.1775 - val_loss: 18.6243
# Epoch 11/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 15.2832 - val_loss: 12.4571
# Epoch 12/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 11.4648 - val_loss: 9.2039
# Epoch 13/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 9.1353 - val_loss: 7.4830
# Epoch 14/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 7.5368 - val_loss: 5.6834
# Epoch 15/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 6.3868 - val_loss: 6.1235
# Epoch 16/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 5.5993 - val_loss: 5.9344
# Epoch 17/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.9863 - val_loss: 4.8649
# Epoch 18/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 4.2705 - val_loss: 4.5777
# Epoch 19/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.9383 - val_loss: 4.1124
# Epoch 20/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.3976 - val_loss: 3.3214
# Epoch 21/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.3239 - val_loss: 2.8441
# Epoch 22/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 3.0310 - val_loss: 2.4942
# Epoch 23/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 2.8473 - val_loss: 2.7680
# Epoch 24/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 2.6343 - val_loss: 3.0173
# Epoch 25/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 2.4731 - val_loss: 2.2140
# Epoch 26/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 2.5632 - val_loss: 3.0200
# Epoch 27/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 2.3313 - val_loss: 1.7884
# Epoch 28/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 2.5943 - val_loss: 2.4524
# Epoch 29/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 2.0198 - val_loss: 2.3561
# Epoch 30/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 2.2468 - val_loss: 1.7823
# Epoch 31/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 2.0815 - val_loss: 1.8012
# Epoch 32/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 2.0970 - val_loss: 2.8801
# Epoch 33/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 2.0159 - val_loss: 1.4384
# Epoch 34/100
# 1021/1021 [==============================] - 3s 3ms/step - loss: 1.8706 - val_loss: 1.3767
# Epoch 35/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.8878 - val_loss: 1.2831
# Epoch 36/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 2.0052 - val_loss: 1.3070
# Epoch 37/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.7980 - val_loss: 1.2401
# Epoch 38/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.8273 - val_loss: 1.3989
# Epoch 39/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.7547 - val_loss: 2.3528
# Epoch 40/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.8865 - val_loss: 1.5760
# Epoch 41/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.8002 - val_loss: 1.6823
# Epoch 42/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.6714 - val_loss: 1.9393
# Epoch 43/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.7518 - val_loss: 1.2688
# Epoch 44/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.6466 - val_loss: 1.5423
# Epoch 45/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.7184 - val_loss: 1.4750
# Epoch 46/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.6532 - val_loss: 1.2234
# Epoch 47/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.4947 - val_loss: 1.2641
# Epoch 48/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.5196 - val_loss: 2.4178
# Epoch 49/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.6115 - val_loss: 2.5369
# Epoch 50/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.4045 - val_loss: 1.0152
# Epoch 51/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.4540 - val_loss: 1.2425
# Epoch 52/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.5179 - val_loss: 1.2750
# Epoch 53/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.3986 - val_loss: 1.3545
# Epoch 54/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.5905 - val_loss: 1.2687
# Epoch 55/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.4259 - val_loss: 1.1839
# Epoch 56/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.4282 - val_loss: 1.8688
# Epoch 57/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.3794 - val_loss: 1.4985
# Epoch 58/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.4402 - val_loss: 5.5440
# Epoch 59/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.4287 - val_loss: 1.4661
# Epoch 60/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.3081 - val_loss: 1.0541
# Epoch 61/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.3928 - val_loss: 1.1759
# Epoch 62/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.2490 - val_loss: 1.2590
# Epoch 63/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.2632 - val_loss: 2.0535
# Epoch 64/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.4896 - val_loss: 1.0656
# Epoch 65/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.2807 - val_loss: 1.7358
# Epoch 66/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.3128 - val_loss: 0.9603
# Epoch 67/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.4057 - val_loss: 0.8754
# Epoch 68/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.3102 - val_loss: 0.8467
# Epoch 69/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.2580 - val_loss: 0.9138
# Epoch 70/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.3020 - val_loss: 1.1017
# Epoch 71/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.3480 - val_loss: 2.9274
# Epoch 72/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.3177 - val_loss: 0.7366
# Epoch 73/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.2425 - val_loss: 1.3789
# Epoch 74/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.2649 - val_loss: 0.9564
# Epoch 75/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.3239 - val_loss: 1.0325
# Epoch 76/100
# 1021/1021 [==============================] - 3s 2ms/step - loss: 1.2751 - val_loss: 0.8515
# Epoch 77/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.1638 - val_loss: 2.6250
# Epoch 78/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.2635 - val_loss: 0.9858
# Epoch 79/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.1815 - val_loss: 1.6651
# Epoch 80/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.2778 - val_loss: 3.9585
# Epoch 81/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.2774 - val_loss: 0.8318
# Epoch 82/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.1134 - val_loss: 1.0492
# Epoch 83/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.1920 - val_loss: 0.8323
# Epoch 84/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.1132 - val_loss: 0.8902
# Epoch 85/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.1428 - val_loss: 1.7336
# Epoch 86/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.1199 - val_loss: 0.8173
# Epoch 87/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.0982 - val_loss: 1.3858
# Epoch 88/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.1030 - val_loss: 1.6863
# Epoch 89/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.3296 - val_loss: 0.9305
# Epoch 90/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.0622 - val_loss: 0.6704
# Epoch 91/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.0575 - val_loss: 0.9030
# Epoch 92/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.1207 - val_loss: 1.0056
# Epoch 93/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.1300 - val_loss: 1.0100
# Epoch 94/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.1848 - val_loss: 2.4571
# Epoch 95/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.1528 - val_loss: 1.1676
# Epoch 96/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.1285 - val_loss: 0.6365
# Epoch 97/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.1002 - val_loss: 0.7778
# Epoch 98/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.1406 - val_loss: 1.3804
# Epoch 99/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.0951 - val_loss: 0.6844
# Epoch 100/100
# 1021/1021 [==============================] - 2s 2ms/step - loss: 1.0810 - val_loss: 0.8358

# %%
# Evaluate the model on the test set
X_test_scaled = scaler.transform(X_test)
predictions = model.predict(X_test_scaled)
# Out:
# 320/320 [==============================] - 1s 1ms/step

# %%
mse = mean_squared_error(y_test, predictions)
print(f'Mean Squared Error on Test Set: {mse}')
# Out:
# Mean Squared Error on Test Set: 0.8346553911431945

# %%
import matplotlib.pyplot as plt
# Plot the training loss and validation loss over epochs
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Predictions on the test set
predictions = model.predict(X_test_scaled)

# Save true values, predictions, and features to a CSV file
result_df = pd.DataFrame({'True_Pac': y_test, 'Predicted_Pac': predictions.flatten()})
result_df.to_csv('predictions.csv', index=False)
# Out:
# 320/320 [==============================] - 0s 1ms/step

# %%
result_df = pd.DataFrame({
    'True_Pac': y_test,
    'Predicted_Pac': predictions.flatten(),
    'Tm': X_test['Tm'],   # Add more columns as needed
    'Ta': X_test['Ta'],
    'Gir': X_test['Gir']
})

# %%
# Sort the DataFrame based on ascending values of 'Ta' and 'Gir'
result_df = result_df.sort_values(by=['Ta', 'Gir'])

# Save the sorted DataFrame to a CSV file
result_df.to_csv('predictions_with_features_sorted_3.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the predictions with features from the CSV file
import_df = pd.read_csv('predictions_with_features_sorted_3.csv')

# Plot 'Ta' vs 'True_Pac' and 'Predicted_Pac' with smaller points
plt.scatter(import_df['Ta'], import_df['True_Pac'], label='True_Pac', s=1)  # Adjust 's' for size
plt.scatter(import_df['Ta'], import_df['Predicted_Pac'], label='Predicted_Pac', s=1)  # Adjust 's' for size
plt.xlabel('Ta')
plt.ylabel('Power Output (Pac)')
plt.title('True vs Predicted Power Output')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the predictions with features from the CSV file
import_df = pd.read_csv('predictions_with_features_sorted_3.csv')

# Filter the DataFrame for Ta = 25
selected_ta_df = import_df[import_df['Ta'] == 25]

# Plot 'Gir' vs 'True_Pac' and 'Predicted_Pac' for Ta = 25
plt.scatter(selected_ta_df['Gir'], selected_ta_df['True_Pac'], label='True_Pac', s=10)
plt.scatter(selected_ta_df['Gir'], selected_ta_df['Predicted_Pac'], label='Predicted_Pac', s=10)
plt.xlabel('Ground Level Sun Irradiance (Gir)')
plt.ylabel('Power Output (Pac)')
plt.title('True vs Predicted Power Output for Ta = 25')
plt.legend()
plt.show()
